# %% [markdown]
# ## Question 1 (3 points)
#
# Implement the function `create_circuit_1` that has
#
# * Inputs: None
# * Returns: a `cirq.Circuit` object of 5 qubits.
#
# The function implements, in order, the following operations:
#
# 1. Construct a quantum circuit with 5 qubits.
# 2. Apply the $H$ gate to each qubit.
# 3. Apply the $Z$ gate to qubits in position 0,2 and 4.
# 4. Apply the $H$ gate to each qubit.

# %%
import cirq
from cirq import H, Z

def create_circuit_1(): 

    circuit = cirq.Circuit()
    
    # Do not modify anything above
    
    # YOUR CODE HERE
    
    qubits = cirq.LineQubit.range(5) # Creating qubits of range upto 5
    circuit.append(H.on_each(*qubits)) # Apply the H gate to each qubit
    circuit.append(Z(qubits[0])) # Apply the Z gate to qubit position 0
    circuit.append(Z(qubits[2])) # Apply the Z gate to qubit position 2
    circuit.append(Z(qubits[4])) # Apply the Z gate to qubit position 4
    circuit.append(H.on_each(*qubits)) # Apply the H gate to each qubit
    
    # Do not modify anything below
    return circuit

# %%
circuit = create_circuit_1()
print(circuit)
# Out:
# 0: ───H───Z───H───
#
# 1: ───H───H───────
#
# 2: ───H───Z───H───
#
# 3: ───H───H───────
#
# 4: ───H───Z───H───
